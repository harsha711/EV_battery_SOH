# %% [markdown]
# # 00 — Preprocessing
#
# Converts raw NASA Randomized Battery Usage `.mat` files into a single HDF5 dataset used by all model notebooks.
#
# **Run this notebook once** before running any model notebook. Output files:
# - `data/processed/sequences.h5` — 450K × (301, 3) float32 sequences + SOH labels (~1.52 GB uncompressed)
# - `data/processed/norm_stats.json` — per-channel mean/std computed on training split only
#
# **Raw data location:** `../../11. Randomized Battery Usage Data Set/` (relative to this notebook)

# %%
import os
import sys
import json
import h5py
import numpy as np

PROJECT_ROOT = os.path.abspath('..')
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.preprocessing import build_sequence_dataset
from src.dataset import BatterySOHDataset, DEFAULT_TEST_BATTERIES

DATA_DIR   = '../../11. Randomized Battery Usage Data Set'
H5_PATH    = '../data/processed/sequences.h5'
STATS_PATH = '../data/processed/norm_stats.json'

print(f'Raw data dir : {os.path.abspath(DATA_DIR)}')
print(f'Raw data exists: {os.path.isdir(DATA_DIR)}')
print(f'Output HDF5  : {os.path.abspath(H5_PATH)}')
# Out:
# Raw data dir : c:\Users\ashin\Desktop\Light\EV_battery_SOH\11. Randomized Battery Usage Data Set
# Raw data exists: True
# Output HDF5  : c:\Users\ashin\Desktop\Light\EV_battery_SOH\project\data\processed\sequences.h5

# %% [markdown]
# ## Step 1 — Build HDF5 Dataset
#
# Iterates all 28 `.mat` files, extracts charge/discharge random-walk steps, resamples each to 301 time points, and labels each step with the SOH from the next reference discharge.
#
# Expected output: ~450K steps, ~2–3 minutes on first run.

# %%
if os.path.exists(H5_PATH):
    print(f'HDF5 already exists at {H5_PATH} — skipping build.')
    print('Delete the file and re-run this cell to rebuild from scratch.')
else:
    build_sequence_dataset(
        data_dir=DATA_DIR,
        output_path=H5_PATH,
    )
# Out:
# Found 28 battery files in '../../11. Randomized Battery Usage Data Set'
#   Processing RW10... 38942 steps, 76 blocks, SOH 40.2–97.9%
#   Processing RW11... 38635 steps, 76 blocks, SOH 33.1–98.2%
#   Processing RW12... 36316 steps, 75 blocks, SOH 52.1–98.9%
#   Processing RW9... 39317 steps, 79 blocks, SOH 35.7–97.5%
#   Processing RW3... 5266 steps, 43 blocks, SOH 52.7–96.7%
#   Processing RW4... 4429 steps, 37 blocks, SOH 57.5–95.1%
#   Processing RW5... 4702 steps, 41 blocks, SOH 56.8–96.0%
#   Processing RW6... 2781 steps, 21 blocks, SOH 67.6–96.2%
#   Processing RW1... 6096 steps, 47 blocks, SOH 57.9–97.9%
#   Processing RW2... 6104 steps, 51 blocks, SOH 56.5–96.4%
#   Processing RW7... 6282 steps, 48 blocks, SOH 52.1–97.4%
#   Processing RW8... 5734 steps, 47 blocks, SOH 54.4–95.4%
#   Processing RW25... 9229 steps, 12 blocks, SOH 78.5–96.9%
#   Processing RW26... 7172 steps, 13 blocks, SOH 84.4–97.0%
#   Processing RW27... 10165 steps, 11 blocks, SOH 81.8–96.8%
#   Processing RW28... 8928 steps, 11 blocks, SOH 82.1–97.7%
#   Processing RW17... 13308 steps, 28 blocks, SOH 0.0–100.3%
#   Processing RW18... 13915 steps, 27 blocks, SOH 0.0–92.1%
#   Processing RW19... 14863 steps, 26 blocks, SOH 0.0–94.0%
#   Processing RW20... 12283 steps, 28 blocks, SOH 48.9–100.2%
#   Processing RW21... 20139 steps, 10 blocks, SOH 76.9–97.4%
#   Processing RW22... 18153 steps, 9 blocks, SOH 66.7–97.4%
#   Processing RW23... 19963 steps, 10 blocks, SOH 74.0–96.9%
#   Processing RW24... 18750 steps, 10 blocks, SOH 77.8–97.3%
#   Processing RW13... 25991 steps, 22 blocks, SOH 51.3–96.5%
#   Processing RW14... 21162 steps, 23 blocks, SOH 41.6–96.4%
#   Processing RW15... 22101 steps, 23 blocks, SOH 44.3–96.5%
#   Processing RW16... 19800 steps, 18 blocks, SOH 45.0–94.3%
#
# Done. 28 batteries, 450,526 total steps.
# Output: ../data/processed/sequences.h5
# X shape: (450526, 301, 3)  ≈ 1.63 GB uncompressed

# %% [markdown]
# ## Step 2 — Verify HDF5 Contents

# %%
with h5py.File(H5_PATH, 'r') as f:
    n   = f['X'].shape[0]
    print('Datasets:')
    for key in f.keys():
        print(f'  {key:12s} {str(f[key].shape):25s} {f[key].dtype}')
    print()
    print('Attributes:')
    for k, v in f.attrs.items():
        print(f'  {k}: {v}')
    print()
    size_gb = f['X'].shape[0] * 301 * 3 * 4 / 1e9
    print(f'Total samples : {n:,}')
    print(f'X uncompressed: {size_gb:.2f} GB')
    print(f'SOH range     : {f["y"][:].min():.1f}% – {f["y"][:].max():.1f}%')
# Out:
# Datasets:
#   X            (450526, 301, 3)          float32
#   battery_id   (450526,)                 |S6
#   block_index  (450526,)                 int32
#   step_type    (450526,)                 |S32
#   y            (450526,)                 float32
#
# Attributes:
#   channels: ['voltage' 'current' 'temperature']
#   created: 2026-04-22T17:54:43.291295
#   min_step_length: 10
#   n_channels: 3
#   n_samples: 450526
#   seq_len: 301
#   soh_unit: percent
#
# Total samples : 450,526
# X uncompressed: 1.63 GB
# SOH range     : 0.0% – 100.3%

# %%
import torch

# %%
print(torch.cuda.get_device_name(0))
print(torch.cuda.memory_allocated())
# Out:
# NVIDIA GeForce RTX 4070 Ti
# 0
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
