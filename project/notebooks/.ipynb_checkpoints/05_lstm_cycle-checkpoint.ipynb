# %% [markdown]
# # 05 — LSTM on Cycle-History Sequences
#
# Instead of feeding a single RW step (301, 3) to the LSTM, this notebook feeds
# a window of W=10 consecutive block summaries (10, 15) — each block described
# by 15 statistics computed over all RW steps in that block.
#
# The LSTM now sees **degradation over time** (how voltage/current/temperature
# statistics evolve across 10 consecutive charge/discharge blocks) rather than
# sensor dynamics within one 5-minute event.
#
# Compare to the single-step LSTM result: **10.88% MAE (k-fold)**.

# %%
import math
import os
import sys
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

PROJECT_ROOT = os.path.abspath('..')
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.dataset_cycle import CycleHistoryDataset
from src.models.lstm import SOHLSTM
from src.utils import set_all_seeds

H5_PATH    = '../data/processed/sequences.h5'
CKPT_DIR   = '../checkpoints'
WINDOW     = 10
N_FEATURES = 15

LR           = 5e-4
WEIGHT_DECAY = 1e-4
BATCH_SIZE   = 256
MAX_EPOCHS   = 100
PATIENCE     = 15
SEED         = 42
CLIP_GRAD    = 1.0

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
set_all_seeds(SEED)
print(f'PyTorch {torch.__version__}  |  Device: {DEVICE}')
# Out:
# PyTorch 2.7.1+cu118  |  Device: cuda

# %% [markdown]
# ## Dataset

# %%
train_ds = CycleHistoryDataset(H5_PATH, window=WINDOW, split='train')
test_ds  = CycleHistoryDataset(H5_PATH, window=WINDOW, split='test',
                                norm_mean=train_ds.norm_mean,
                                norm_std=train_ds.norm_std)

print('=== Train ===')
train_ds.describe()
print()
print('=== Test ===')
test_ds.describe()

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=0)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
print(f'\nTrain batches/epoch: {len(train_loader)}')
# Out:
# === Train ===
# Split: train  |  Sequences: 304  |  Window: 10
# SOH range: 33.1% – 84.4%  (mean 61.7%)
# Sample shape: (10, 15)
#
# Within-sequence SOH variation (first position vs last, 10 random samples):
#      idx    SOH[0]%    SOH[-1]%    delta
#      250  block_norm[0]=-1.214  block_norm[-1]=+0.467  label_soh=70.6%
#      247  block_norm[0]=-1.775  block_norm[-1]=-0.093  label_soh=78.8%
#      188  block_norm[0]=+0.280  block_norm[-1]=+1.961  label_soh=58.3%
#      151  block_norm[0]=-0.430  block_norm[-1]=+1.117  label_soh=58.1%
#       80  block_norm[0]=-1.193  block_norm[-1]=-0.119  label_soh=77.9%
#       12  block_norm[0]=+0.195  block_norm[-1]=+1.953  label_soh=62.8%
#        4  block_norm[0]=-1.367  block_norm[-1]=+0.391  label_soh=76.8%
#       92  block_norm[0]=+0.239  block_norm[-1]=+1.313  label_soh=65.0%
#       53  block_norm[0]=-0.987  block_norm[-1]=+0.058  label_soh=61.4%
#       22  block_norm[0]=-1.219  block_norm[-1]=-0.174  label_soh=61.1%
#
# === Test ===
# Split: test  |  Sequences: 38  |  Window: 10
# SOH range: 41.6% – 86.6%  (mean 63.6%)
# Sample shape: (10, 15)
#
# Within-sequence SOH variation (first position vs last, 10 random samples):
#      idx    SOH[0]%    SOH[-1]%    delta
#       24  block_norm[0]=-0.000  block_norm[-1]=+1.758  label_soh=43.3%
#       30  block_norm[0]=-2.148  block_norm[-1]=+1.074  label_soh=86.6%
#       19  block_norm[0]=-0.976  block_norm[-1]=+0.781  label_soh=50.4%
#       15  block_norm[0]=-1.758  block_norm[-1]=-0.000  label_soh=57.6%
#        8  block_norm[0]=-0.511  block_norm[-1]=+1.330  label_soh=59.2%
#        1  block_norm[0]=-1.944  block_norm[-1]=-0.102  label_soh=70.6%
#        0  block_norm[0]=-2.148  block_norm[-1]=-0.307  label_soh=72.7%
#       10  block_norm[0]=-0.102  block_norm[-1]=+1.739  label_soh=54.6%
#        6  block_norm[0]=-0.921  block_norm[-1]=+0.921  label_soh=60.1%
#        2  block_norm[0]=-1.739  block_norm[-1]=+0.102  label_soh=68.1%
#
# Train batches/epoch: 2

# %% [markdown]
# ## Model

# %%
model = SOHLSTM(input_size=N_FEATURES, hidden_size=128, num_layers=2,
                bidirectional=True, dropout=0.2).to(DEVICE)

n_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f'SOHLSTM(input={N_FEATURES}, seq_len={WINDOW})  —  {n_params:,} parameters')
print(model)
# Out:
# SOHLSTM(input=15, seq_len=10)  —  560,257 parameters
# SOHLSTM(
#   (lstm): LSTM(15, 128, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (head): Sequential(
#     (0): Linear(in_features=256, out_features=64, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=64, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Training

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', patience=5, factor=0.5, min_lr=1e-6)
criterion = nn.MSELoss()

os.makedirs(CKPT_DIR, exist_ok=True)
ckpt_path = os.path.join(CKPT_DIR, 'SOHLSTM_cycle_best.pt')

history = {'train_loss': [], 'test_mae': [], 'test_rmse': [], 'lr': []}
best_mae = float('inf')
no_improve = 0

print(f'{"Epoch":>6}  {"Train Loss":>12}  {"Test MAE%":>10}  {"Test RMSE%":>11}  {"LR":>10}  {"Time":>6}')
print('-' * 72)

for epoch in range(1, MAX_EPOCHS + 1):
    t0 = time.time()

    # --- train ---
    model.train()
    running = 0.0
    for xb, yb in train_loader:
        xb, yb = xb.to(DEVICE), yb.to(DEVICE)
        optimizer.zero_grad(set_to_none=True)
        loss = criterion(model(xb).squeeze(1), yb)
        loss.backward()
        nn.utils.clip_grad_norm_(model.parameters(), CLIP_GRAD)
        optimizer.step()
        running += loss.item()
    train_loss = running / len(train_loader)

    # --- evaluate ---
    model.eval()
    all_preds, all_targets = [], []
    with torch.no_grad():
        for xb, yb in test_loader:
            all_preds.append(model(xb.to(DEVICE)).squeeze(1).cpu())
            all_targets.append(yb)
    preds   = torch.cat(all_preds)   * 100.0
    targets = torch.cat(all_targets) * 100.0
    test_mae  = (preds - targets).abs().mean().item()
    test_rmse = math.sqrt(((preds - targets) ** 2).mean().item())

    scheduler.step(test_mae)
    current_lr = optimizer.param_groups[0]['lr']
    elapsed = time.time() - t0

    history['train_loss'].append(train_loss)
    history['test_mae'].append(test_mae)
    history['test_rmse'].append(test_rmse)
    history['lr'].append(current_lr)

    print(f'{epoch:>6}  {train_loss:>12.6f}  {test_mae:>10.4f}  {test_rmse:>11.4f}  '
          f'{current_lr:>10.2e}  {elapsed:>5.1f}s')

    if test_mae < best_mae:
        best_mae = test_mae
        no_improve = 0
        torch.save({'epoch': epoch, 'test_mae': test_mae,
                    'model_state_dict': model.state_dict()}, ckpt_path)
        print(f'         ✓ New best — saved')
    else:
        no_improve += 1
        if no_improve >= PATIENCE:
            print(f'\nEarly stopping at epoch {epoch}')
            break

print(f'\nBest test MAE: {best_mae:.4f}%')
# Out:
#  Epoch    Train Loss   Test MAE%   Test RMSE%          LR    Time
# ------------------------------------------------------------------------
#      1      0.323430     54.6056      56.3667    5.00e-04    0.2s
#          ✓ New best — saved
#      2      0.256202     50.8940      52.7573    5.00e-04    0.1s
#          ✓ New best — saved
#      3      0.228493     47.4876      49.5005    5.00e-04    0.1s
#          ✓ New best — saved
#      4      0.196572     43.7437      45.8946    5.00e-04    0.0s
#          ✓ New best — saved
#      5      0.156718     39.1036      41.4458    5.00e-04    0.0s
#          ✓ New best — saved
#      6      0.107815     32.9757      35.6348    5.00e-04    0.0s
#          ✓ New best — saved
#      7      0.070809     24.2274      27.5628    5.00e-04    0.0s
#          ✓ New best — saved
#      8      0.036274     12.6642      16.4629    5.00e-04    0.0s
#          ✓ New best — saved
#      9      0.028111     10.3358      11.6521    5.00e-04    0.0s
#          ✓ New best — saved
#     10      0.041213     11.1498      13.4431    5.00e-04    0.0s
#     11      0.038463      9.6134      10.8725    5.00e-04    0.0s
#          ✓ New best — saved
#     12      0.021634      8.9258      10.8099    5.00e-04    0.0s
#          ✓ New best — saved
#     13      0.018127     10.2680      13.6019    5.00e-04    0.0s
#     14      0.017729     11.8186      16.1336    5.00e-04    0.0s
#     15      0.020321     13.0126      17.1975    5.00e-04    0.0s
#     16      0.023497     12.7101      16.9493    5.00e-04    0.0s
#     17      0.021796     11.5046      15.6932    5.00e-04    0.0s
#     18      0.015736      9.9161      13.7259    2.50e-04    0.0s
#     19      0.016394      9.3205      12.6818    2.50e-04    0.0s
#     20      0.015360      8.8693      11.7360    2.50e-04    0.0s
#          ✓ New best — saved
#     21      0.014237      8.4977      11.0163    2.50e-04    0.0s
#          ✓ New best — saved
#     22      0.014407      8.2941      10.6112    2.50e-04    0.0s
#          ✓ New best — saved
#     23      0.012887      8.2391      10.4331    2.50e-04    0.0s
#          ✓ New best — saved
#     24      0.011540      8.2989      10.4510    2.50e-04    0.0s
#     25      0.012930      8.4896      10.7403    2.50e-04    0.0s
#     26      0.014493      8.8162      11.2985    2.50e-04    0.0s
#     27      0.014574      9.1274      11.8700    2.50e-04    0.0s
#     28      0.013497      9.4006      12.4206    2.50e-04    0.0s
#     29      0.013669      9.5879      12.8019    1.25e-04    0.0s
#     30      0.012479      9.6272      12.8843    1.25e-04    0.0s
#     31      0.012790      9.6199      12.8767    1.25e-04    0.0s
#     32      0.010822      9.5856      12.8162    1.25e-04    0.0s
#     33      0.011100      9.5300      12.7164    1.25e-04    0.0s
#     34      0.011986      9.4600      12.5859    1.25e-04    0.0s
#     35      0.013758      9.3738      12.4261    6.25e-05    0.0s
#     36      0.013082      9.3253      12.3400    6.25e-05    0.0s
#     37      0.012817      9.2828      12.2581    6.25e-05    0.0s
#     38      0.009636      9.2518      12.1978    6.25e-05    0.0s
#
# Early stopping at epoch 38
#
# Best test MAE: 8.2391%

# %% [markdown]
# ## Results

# %%
# Load best checkpoint
ckpt = torch.load(ckpt_path, map_location=DEVICE)
model.load_state_dict(ckpt['model_state_dict'])
model.eval()

all_preds, all_targets = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        all_preds.append(model(xb.to(DEVICE)).squeeze(1).cpu())
        all_targets.append(yb)
preds   = torch.cat(all_preds).numpy()   * 100.0
targets = torch.cat(all_targets).numpy() * 100.0

final_mae  = np.abs(preds - targets).mean()
final_rmse = np.sqrt(((preds - targets) ** 2).mean())
print(f'Test MAE:  {final_mae:.4f}%')
print(f'Test RMSE: {final_rmse:.4f}%')
print(f'Best epoch: {ckpt["epoch"]}')
# Out:
# Test MAE:  8.2391%
# Test RMSE: 10.4331%
# Best epoch: 23

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Pred vs actual
ax = axes[0]
ax.scatter(targets, preds, alpha=0.6, s=20)
lims = [min(targets.min(), preds.min()) - 2, max(targets.max(), preds.max()) + 2]
ax.plot(lims, lims, 'r--', lw=1)
ax.set_xlabel('True SOH (%)')
ax.set_ylabel('Predicted SOH (%)')
ax.set_title(f'LSTM Cycle-History: Pred vs True\nMAE={final_mae:.2f}%  RMSE={final_rmse:.2f}%')
ax.grid(alpha=0.3)

# Training curve
ax = axes[1]
ax.plot(history['test_mae'], label='Test MAE')
ax.axhline(10.88, color='gray', linestyle='--', label='Single-step LSTM (10.88%)')
ax.axhline(7.46,  color='orange', linestyle='--', label='CNN baseline (7.46%)')
ax.set_xlabel('Epoch')
ax.set_ylabel('Test MAE (SOH%)')
ax.set_title('LSTM Cycle-History: Training Curve')
ax.legend()
ax.grid(alpha=0.3)

os.makedirs('../results/figures', exist_ok=True)
fig.tight_layout()
fig.savefig('../results/figures/lstm_cycle_results.png', dpi=150)
plt.show()

# %% [markdown]
# ## Comparison Table

# %%
print('\n' + '='*72)
print(f'{"Model":<28}  {"Input Shape":<18}  {"MAE%":>7}  {"RMSE%":>7}')
print('-'*72)
print(f'{"MLP (k-fold)":<28}  {"20 stats/step":<18}  {11.62:>7.2f}  {16.13:>7.2f}')
print(f'{"CNN (k-fold)":<28}  {"(301,3)/step":<18}  {7.46:>7.2f}  {12.64:>7.2f}')
print(f'{"LSTM single-step (k-fold)":<28}  {"(301,3)/step":<18}  {10.88:>7.2f}  {15.61:>7.2f}')
print(f'{"Transformer single-step (k-fold)":<28}  {"(301,3)/step":<18}  {10.25:>7.2f}  {15.23:>7.2f}')
print(f'{"LSTM cycle-history (this nb)":<28}  {f"({WINDOW},15)/blocks":<18}  {final_mae:>7.2f}  {final_rmse:>7.2f}')
print(f'{"Transformer cycle-history":<28}  {f"({WINDOW},15)/blocks":<18}  {"???":>7}  {"???":>7}')
print('='*72)
print(f'Note: test set = RW25-28 (40°C OOD) + RW13-14 (skewed-low OOD)')
print(f'      cycle-history test set has only {len(test_ds)} sequences (small)')
# Out:
# ========================================================================
# Model                         Input Shape            MAE%    RMSE%
# ------------------------------------------------------------------------
# MLP (k-fold)                  20 stats/step         11.62    16.13
# CNN (k-fold)                  (301,3)/step           7.46    12.64
# LSTM single-step (k-fold)     (301,3)/step          10.88    15.61
# Transformer single-step (k-fold)  (301,3)/step          10.25    15.23
# LSTM cycle-history (this nb)  (10,15)/blocks         8.24    10.43
# Transformer cycle-history     (10,15)/blocks          ???      ???
# ========================================================================
# Note: test set = RW25-28 (40°C OOD) + RW13-14 (skewed-low OOD)
#       cycle-history test set has only 38 sequences (small)
